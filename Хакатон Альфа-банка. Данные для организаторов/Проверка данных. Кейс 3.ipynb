# %%
import pandas as pd
from sklearn.metrics import roc_auc_score
import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_train = '/content/drive/MyDrive/Хакатон Альфа-банка. Кейс 3/train'
path_test = '/content/drive/MyDrive/Хакатон Альфа-банка. Кейс 3/test'

# %%
trains = sorted(glob.glob(path_train+'/*.csv'), key=lambda x: int(x[-5]))
tests = sorted(glob.glob(path_test+'/*.csv'), key=lambda x: int(x[-5]))

# %% [markdown]
# Проверка на одинаковое количество столбцов в файлах train

# %%
for pt in trains:
  data = pd.read_csv(pt)
  print('Размерность файла {} составляет {} строк и {} столбцов'.format(pt.split('/')[-1],*data.shape))
# Out:
# Размерность файла train_10.csv составляет 41323 строк и 189 столбцов
# Размерность файла train_1.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_2.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_3.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_4.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_5.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_6.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_7.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_8.csv составляет 41319 строк и 189 столбцов
# Размерность файла train_9.csv составляет 41319 строк и 189 столбцов

# %% [markdown]
# Проверка на одинаковое количество столбцов в файлах test

# %%
for pt in tests:
  data = pd.read_csv(pt)
  print('Размерность файла {} составляет {} строк и {} столбцов'.format(pt.split('/')[-1],*data.shape))
# Out:
# Размерность файла test_10.csv составляет 17200 строк и 188 столбцов
# Размерность файла test_1.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_2.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_3.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_4.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_5.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_6.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_7.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_8.csv составляет 17191 строк и 188 столбцов
# Размерность файла test_9.csv составляет 17191 строк и 188 столбцов

# %% [markdown]
# Проверка на равенство с изначальными test, за вычетом столбца target

# %%
tests_with_target = '/content/drive/MyDrive/Хакатон Альфа-банка. Данные для организаторов/test with target. Кейс 3'
tests_w_target = sorted(glob.glob(tests_with_target+'/*.csv'), key=lambda x: int(x[-5]))

# %%
for i in range(len(tests_w_target)):
  data1 = pd.read_csv(tests_w_target[i]).drop(['target'], axis=1)
  data2 = pd.read_csv(tests[i])
  print('''
  Размерность изначального файла {} без target - {} строк и {} столбцов
  Размерность обработанного файла {} - {} строк и {} столбцов
  Число строк в обоих файлах равно - {}
  Число столбцов в обоих файлах равно - {}
  Фыйлы равны друг другу {}
  '''.format(tests_w_target[i].split('/')[-1], *data1.shape,
             tests[i].split('/')[-1], *data2.shape,
             data1.shape[0]==data2.shape[0],
             data2.shape[0]==data2.shape[0],
             data1.equals(data2)))
# Out:
#   Размерность изначального файла test_10.csv без target - 17200 строк и 188 столбцов
#   Размерность обработанного файла test_10.csv - 17200 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_1.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_1.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_2.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_2.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_3.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_3.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_4.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_4.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_5.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_5.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_6.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_6.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_7.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_7.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_8.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_8.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True
#
#
#   Размерность изначального файла test_9.csv без target - 17191 строк и 188 столбцов
#   Размерность обработанного файла test_9.csv - 17191 строк и 188 столбцов
#   Число строк в обоих файлах равно - True
#   Число столбцов в обоих файлах равно - True
#   Фыйлы равны друг другу True

# %% [markdown]
# Проверка на отсутствие столбцов target в данных test

# %%
for pt in tests:
  data = pd.read_csv(pt)
  print('Файл {} не содержит столбца target'.format(pt.split('/')[-1]) if 'target' not in data.columns \
        else 'Файл {} СОДЖЕРИТ СТОЛБЕЦ target. ТРЕВОГА!'.format(pt.split('/')[-1]))
# Out:
# Файл test_10.csv не содержит столбца target
# Файл test_1.csv не содержит столбца target
# Файл test_2.csv не содержит столбца target
# Файл test_3.csv не содержит столбца target
# Файл test_4.csv не содержит столбца target
# Файл test_5.csv не содержит столбца target
# Файл test_6.csv не содержит столбца target
# Файл test_7.csv не содержит столбца target
# Файл test_8.csv не содержит столбца target
# Файл test_9.csv не содержит столбца target

# %% [markdown]
# Рассчет предсказания

# %%
submission = pd.read_csv('/content/drive/MyDrive/Хакатон Альфа-банка. Кейс 3/baseline_submission_case3.csv')
targets = pd.read_csv('/content/drive/MyDrive/Хакатон Альфа-банка. Данные для организаторов/targets/targets_case3.csv')

print(submission.shape)
print(targets.shape)

display(submission.head())
display(targets.head())

display(submission['target'].value_counts())
display(targets['target'].value_counts())
# Out:
# (171919, 2)
# (171919, 2)
#        id    target
# 0  413194  0.116850
# 1  413195  0.020472
# 2  413196  0.033094
# 3  413197  0.005849
# 4  413198  0.053161
#        id  target
# 0  413194       0
# 1  413195       0
# 2  413196       0
# 3  413197       0
# 4  413198       0
# target
# 0.196650    2381
# 0.004996     679
# 0.197853     659
# 0.193734     659
# 0.198196     644
#             ...
# 0.134908       1
# 0.075167       1
# 0.030050       1
# 0.040039       1
# 0.110966       1
# Name: count, Length: 154552, dtype: int64
# target
# 0    160166
# 1     11753
# Name: count, dtype: int64

# %%
submission = submission[['id', 'target']]
targets = targets[['id', 'target']]

result = submission.merge(targets, left_on=['id'], right_on=['id'])

prediction = result.iloc[:, 1]
y_true = result.iloc[:, 2]

metric = max(roc_auc_score(y_true=y_true, y_score=prediction), 1-roc_auc_score(y_true=y_true, y_score=prediction))

print(f'Результат метрики roc-auc на полученных данных равняется {metric}')
# Out:
# Результат метрики roc-auc на полученных данных равняется 0.8102773693275104

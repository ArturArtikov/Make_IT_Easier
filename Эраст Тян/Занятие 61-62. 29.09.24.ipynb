# %%
pip install pytelegrambotapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import telebot
token = "7784012203:AAEar779243hav-mfzSupMhpq5Vya5FOq5M"
bot = telebot.TeleBot(token)

@bot.message_handler(content_types=['text'])
def start(message):
  if message.text == '/start':
    bot.send_message(message.from_user.id, "Привет, как тебя зовут?")
    bot.register_next_step_handler(message, get_name)
  else:
    bot.send_message(message.from_user.id, "Напиши /start")

def get_name(message):
  bot.send_message(message.from_user.id, f'Тебя зовут {message.text} ?')
  bot.register_next_step_handler(message, answer)

def answer(message):
  if message.text.upper() == 'ДА':
    bot.send_message(message.from_user.id, "У тебя очень красивое имя!")
  else:
    bot.send_message(message.from_user.id, "Простите, я ошибся :(")


bot.polling(non_stop=True, interval=0)

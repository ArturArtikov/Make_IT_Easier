# %%
import pandas as pd
from sklearn.metrics import roc_auc_score

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
submission = pd.read_csv('/content/drive/MyDrive/Alfa Hack. Final. Notebooks/test_submissions/private/test_submission_margin_propensity.csv')
print(submission.shape)
# Out:
# (342493, 2)

# %%
targets = pd.read_csv('/content/drive/MyDrive/Alfa Hack. Final. Submissions/private/margin_propensity.csv')
print(targets.shape)
# Out:
# (342493, 2)

# %%
targets.head()
# Out:
#        id  target
# 0  657507       0
# 1  657508       0
# 2  657509       0
# 3  657510       0
# 4  657511       0

# %%
submission.head()
# Out:
#        id    target
# 0  657507  0.055184
# 1  657508  0.112381
# 2  657509  0.021034
# 3  657510  0.060656
# 4  657511  0.224602

# %% [markdown]
# ## Расчет метрики

# %%
submission = submission[['id', 'target']]
targets = targets[['id', 'target']]

result = submission.merge(targets, left_on=['id'], right_on=['id'])

prediction = result.iloc[:, 1]
y_true = result.iloc[:, 2]

metric = max(roc_auc_score(y_true=y_true, y_score=prediction), 1-roc_auc_score(y_true=y_true, y_score=prediction))

print(f'Результат метрики roc-auc на полученных данных равняется {metric}')
# Out:
# Результат метрики roc-auc на полученных данных равняется 0.644929465298103

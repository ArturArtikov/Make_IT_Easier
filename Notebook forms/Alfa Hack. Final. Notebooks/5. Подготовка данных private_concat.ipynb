# %%
# Для обработки файлов
import pandas as pd
# Для объединения данных
import glob
# Для работы с операционной системой
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
public_start = '/content/drive/MyDrive/Alfa Hack. Final. Data/private'
public_end = '/content/drive/MyDrive/Alfa Hack. Concat data/private'

# %%
# Получим список датасетов в изначальной папке
folders_start = os.listdir(public_start)
print(folders_start)
# Out:
# ['margin_propensity', 'antispam', 'leasing_propensity_ul', 'fl_loan_tendency', 'acquire_propensity_ul']

# %%
# Копируем папки без файлов
for fold_start in folders_start:
  path = os.path.join(public_end, fold_start)
  os.mkdir(path)

# %%
# Копируем папки test и train
for fold_start in folders_start:
  path_train = os.path.join(public_end, fold_start+'/train')
  path_test = os.path.join(public_end, fold_start+'/test')
  os.mkdir(path_train)
  os.mkdir(path_test)

# %% [markdown]
# ## Перевод train в parquet

# %%
def train_transfer(start_path, end_path):
  # train в изначальной папке
  start_train = start_path + '/train'
  # train в конечной папке
  end_train = end_path + '/train'
  # Список файлов в изначальной папке
  start_train_data = os.listdir(start_train)
  # Перегонка файлов
  for file in start_train_data:
    path = start_train + f'/{file}'
    data = pd.read_csv(path)
    data.to_parquet(end_train+f'/{file.replace(".csv", ".parquet")}', index=False)
    print(f' * Файл {file} успешно перенесен')
  print("="*100)

# %%
# Получим список датасетов в основной папке
public_start_folders = os.listdir(public_start)
# Получим список датасетов в конечной папке
public_end_folders = os.listdir(public_end)

for folder in public_start_folders:
  print(f'Папка {folder}')
  train_transfer(start_path=public_start+f'/{folder}',
                 end_path=public_end+f'/{folder}')
# Out:
# Папка margin_propensity
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка antispam
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка leasing_propensity_ul
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка fl_loan_tendency
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка acquire_propensity_ul
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================

# %% [markdown]
# ## Перевод test

# %%
def test_transfer(start_path, end_path):
  # train в изначальной папке
  start_test = start_path + '/test'
  # train в конечной папке
  end_test = end_path + '/test'
  # Список файлов в изначальной папке
  start_test_data = os.listdir(start_test)
  # Перегонка файлов
  for file in start_test_data:
    path = start_test + f'/{file}'
    data = pd.read_csv(path)
    # Сохраняем датасет
    data.to_parquet(end_test+f'/{file.replace(".csv", ".parquet")}', index=False)
    print(f' * Файл {file} успешно перенесен')
  print("="*100)

# %%
for folder in public_start_folders:
  print(f'Папка {folder}')
  test_transfer(start_path=public_start+f'/{folder}',
                 end_path=public_end+f'/{folder}')
# Out:
# Папка margin_propensity
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка antispam
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка leasing_propensity_ul
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка fl_loan_tendency
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка acquire_propensity_ul
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================

# %% [markdown]
# ## Проверка размерности данных

# %%
def check_data(folder_path):
  # Найдем путь к конечным данным train
  train_end_path = folder_path + '/train'
  # Надем путь к конечным данным test
  test_end_path = folder_path + '/test'
  # Получим список файлов в папке train
  train_files = os.listdir(train_end_path)
  # Получим список файлов в папке test
  test_files = os.listdir(test_end_path)

  for train in train_files:
    # Получим путь к файлу
    train_path = train_end_path + f'/{train}'
    # Считаем данные по пути
    data = pd.read_parquet(train_path)
    # Выведем информацию о файле
    print(f" * Файл {train} имеет размерность {data.shape[0]} строк и {data.shape[1]} столбцов")

  print("-"*100)

  for test in test_files:
    # Получим путь к файлу
    test_path = test_end_path + f'/{test}'
    # Считаем данные по пути
    data = pd.read_parquet(test_path)
    # Выведем информацию о файле
    print(f" * Файл {test} имеет размерность {data.shape[0]} строк и {data.shape[1]} столбцов")

  print("="*100+'\n')

# %%
# Список датасетов в конечной папке
folders_end = os.listdir(public_end)

for fold_end in folders_end:
  print(f"Папка {fold_end}")
  check_data(folder_path=public_end+f'/{fold_end}')
# Out:
# Папка margin_propensity
#  * Файл train_1.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 65750 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 65757 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 34249 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 34252 строк и 502 столбцов
# ====================================================================================================
#
# Папка antispam
#  * Файл train_1.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 67559 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 67559 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 32441 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 32441 строк и 502 столбцов
# ====================================================================================================
#
# Папка leasing_propensity_ul
#  * Файл train_1.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 66519 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 66524 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 33480 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 33485 строк и 502 столбцов
# ====================================================================================================
#
# Папка fl_loan_tendency
#  * Файл train_1.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 89422 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 89426 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 10577 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 10583 строк и 502 столбцов
# ====================================================================================================
#
# Папка acquire_propensity_ul
#  * Файл train_1.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 70950 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 70956 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 29049 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 29053 строк и 502 столбцов
# ====================================================================================================

# %%
begin = '/content/drive/MyDrive/Alfa Hack. Concat data/private/margin_propensity/train'
end = '/content/drive/MyDrive/AH. Parquet/private/margin_propensity'

files = []
begin_data = os.listdir(begin)

for file in begin_data:
  path = begin + f"/{file}"
  data = pd.read_parquet(path)
  files.append(data)

# Объединяем данные
files = pd.concat(files, ignore_index=True)
# Сохраняем данные
files.to_parquet(end+"/margin_propensity_train.parquet", index=False)

# %%
# Ссылка на объединенные данные
private = "/content/drive/MyDrive/AH. Parquet/private"
# Список файлов в папке
private_folders = os.listdir(private)
# Вывод информации о файлах:
for fold in private_folders:
  # Путь к тестовым файлам
  path_test = private + f"/{fold}"
  # Получаем список файлов во внутренней папке
  files = os.listdir(path_test)
  # Открываем файлы
  for data in files:
    # Создаем путь к файлу
    data_path = path_test + f'/{data}'
    # Открываем файл
    curent_file = pd.read_parquet(data_path)
    # Выводим информацию о файле
    print("Файл {} имеет размерность {} строк и {} столбцов".format(data, curent_file.shape[0], curent_file.shape[1]))
  # Выведем разделитель
  print("="*50+"\n")
# Out:
# Файл acquire_propensity_ul_test.parquet имеет размерность 290494 строк и 502 столбцов
# Файл acquire_propensity_ul_train.parquet имеет размерность 709506 строк и 503 столбцов
# ==================================================
#
# Файл leasing_propensity_ul_test.parquet имеет размерность 334805 строк и 502 столбцов
# Файл leasing_propensity_ul_train.parquet имеет размерность 665195 строк и 503 столбцов
# ==================================================
#
# Файл fl_loan_tendency_test.parquet имеет размерность 105776 строк и 502 столбцов
# Файл fl_loan_tendency_train.parquet имеет размерность 894224 строк и 503 столбцов
# ==================================================
#
# Файл antispam_test.parquet имеет размерность 324410 строк и 502 столбцов
# Файл antispam_train.parquet имеет размерность 675590 строк и 503 столбцов
# ==================================================
#
# Файл margin_propensity_test.parquet имеет размерность 342493 строк и 502 столбцов
# Файл margin_propensity_train.parquet имеет размерность 657507 строк и 503 столбцов
# ==================================================

# %%
print(65750*10+7)

print(34249*10+3)

print()

print(67559*10)

print(32441*10)

print()

print(66519*10+5)

print(33480*10+5)

print()

print(89422*10+4)

print(10577*10+6)

print()

print(70950*10+6)

print(29049*10+4)

print()
# Out:
# 657507
# 342493
#
# 675590
# 324410
#
# 665195
# 334805
#
# 894224
# 105776
#
# 709506
# 290494

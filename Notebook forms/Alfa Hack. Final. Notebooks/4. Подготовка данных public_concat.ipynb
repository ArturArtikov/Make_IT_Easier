# %%
# Для обработки файлов
import pandas as pd
# Для объединения данных
import glob
# Для работы с операционной системой
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
public_start = '/content/drive/MyDrive/Alfa Hack. Final. Data/public'
public_end = '/content/drive/MyDrive/Alfa Hack. Concat data/public'

# %%
# Получим список датасетов в изначальной папке
folders_start = os.listdir(public_start)
print(folders_start)
# Out:
# ['salary_outflow_fl', 'rko_propensity', 'osago_affinity', 'acquire_outflow_ul']

# %%
# Копируем папки без файлов
for fold_start in folders_start:
  path = os.path.join(public_end, fold_start)
  os.mkdir(path)

# %%
# Копируем папки test и train
for fold_start in folders_start:
  path_train = os.path.join(public_end, fold_start+'/train')
  path_test = os.path.join(public_end, fold_start+'/test')
  os.mkdir(path_train)
  os.mkdir(path_test)

# %% [markdown]
# ## Перевод train в parquet

# %%
def train_transfer(start_path, end_path):
  # train в изначальной папке
  start_train = start_path + '/train'
  # train в конечной папке
  end_train = end_path + '/train'
  # Список файлов в изначальной папке
  start_train_data = os.listdir(start_train)
  # Перегонка файлов
  for file in start_train_data:
    path = start_train + f'/{file}'
    data = pd.read_csv(path)
    data.to_parquet(end_train+f'/{file.replace(".csv", ".parquet")}', index=False)
    print(f' * Файл {file} успешно перенесен')
  print("="*100)

# %%
# Получим список датасетов в основной папке
public_start_folders = os.listdir(public_start)
# Получим список датасетов в конечной папке
public_end_folders = os.listdir(public_end)

for folder in public_start_folders:
  print(f'Папка {folder}')
  train_transfer(start_path=public_start+f'/{folder}',
                 end_path=public_end+f'/{folder}')
# Out:
# Папка salary_outflow_fl
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка rko_propensity
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка osago_affinity
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================
# Папка acquire_outflow_ul
#  * Файл train_1.csv успешно перенесен
#  * Файл train_2.csv успешно перенесен
#  * Файл train_3.csv успешно перенесен
#  * Файл train_4.csv успешно перенесен
#  * Файл train_5.csv успешно перенесен
#  * Файл train_6.csv успешно перенесен
#  * Файл train_7.csv успешно перенесен
#  * Файл train_8.csv успешно перенесен
#  * Файл train_9.csv успешно перенесен
#  * Файл train_10.csv успешно перенесен
# ====================================================================================================

# %% [markdown]
# ## Перевод test

# %%
def test_transfer(start_path, end_path):
  # train в изначальной папке
  start_test = start_path + '/test'
  # train в конечной папке
  end_test = end_path + '/test'
  # Список файлов в изначальной папке
  start_test_data = os.listdir(start_test)
  # Перегонка файлов
  for file in start_test_data:
    path = start_test + f'/{file}'
    data = pd.read_csv(path)
    # Сохраняем датасет
    data.to_parquet(end_test+f'/{file.replace(".csv", ".parquet")}', index=False)
    print(f' * Файл {file} успешно перенесен')
  print("="*100)

# %%
for folder in public_start_folders:
  print(f'Папка {folder}')
  test_transfer(start_path=public_start+f'/{folder}',
                 end_path=public_end+f'/{folder}')
# Out:
# Папка salary_outflow_fl
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка rko_propensity
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка osago_affinity
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================
# Папка acquire_outflow_ul
#  * Файл test_1.csv успешно перенесен
#  * Файл test_2.csv успешно перенесен
#  * Файл test_3.csv успешно перенесен
#  * Файл test_4.csv успешно перенесен
#  * Файл test_5.csv успешно перенесен
#  * Файл test_6.csv успешно перенесен
#  * Файл test_7.csv успешно перенесен
#  * Файл test_8.csv успешно перенесен
#  * Файл test_9.csv успешно перенесен
#  * Файл test_10.csv успешно перенесен
# ====================================================================================================

# %% [markdown]
# ## Проверка размерности данных

# %%
def check_data(folder_path):
  # Найдем путь к конечным данным train
  train_end_path = folder_path + '/train'
  # Надем путь к конечным данным test
  test_end_path = folder_path + '/test'
  # Получим список файлов в папке train
  train_files = os.listdir(train_end_path)
  # Получим список файлов в папке test
  test_files = os.listdir(test_end_path)

  for train in train_files:
    # Получим путь к файлу
    train_path = train_end_path + f'/{train}'
    # Считаем данные по пути
    data = pd.read_parquet(train_path)
    # Выведем информацию о файле
    print(f" * Файл {train} имеет размерность {data.shape[0]} строк и {data.shape[1]} столбцов")

  print("-"*100)

  for test in test_files:
    # Получим путь к файлу
    test_path = test_end_path + f'/{test}'
    # Считаем данные по пути
    data = pd.read_parquet(test_path)
    # Выведем информацию о файле
    print(f" * Файл {test} имеет размерность {data.shape[0]} строк и {data.shape[1]} столбцов")

  print("="*100+'\n')

# %%
# Список датасетов в конечной папке
folders_end = os.listdir(public_end)

for fold_end in folders_end:
  print(f"Папка {fold_end}")
  check_data(folder_path=public_end+f'/{fold_end}')
# Out:
# Папка salary_outflow_fl
#  * Файл train_1.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 72970 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 72977 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 27029 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 27032 строк и 502 столбцов
# ====================================================================================================
#
# Папка rko_propensity
#  * Файл train_1.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 69524 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 69533 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 30475 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 30476 строк и 502 столбцов
# ====================================================================================================
#
# Папка osago_affinity
#  * Файл train_1.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_2.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_3.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_4.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_5.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_6.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_7.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_8.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_9.parquet имеет размерность 60798 строк и 503 столбцов
#  * Файл train_10.parquet имеет размерность 60799 строк и 503 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_2.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_3.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_4.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_5.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_6.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_7.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_8.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_9.parquet имеет размерность 39201 строк и 502 столбцов
#  * Файл test_10.parquet имеет размерность 39210 строк и 502 столбцов
# ====================================================================================================
#
# Папка acquire_outflow_ul
#  * Файл train_1.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_2.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_3.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_4.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_5.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_6.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_7.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_8.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_9.parquet имеет размерность 66941 строк и 364 столбцов
#  * Файл train_10.parquet имеет размерность 66950 строк и 364 столбцов
# ----------------------------------------------------------------------------------------------------
#  * Файл test_1.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_2.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_3.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_4.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_5.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_6.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_7.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_8.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_9.parquet имеет размерность 33058 строк и 363 столбцов
#  * Файл test_10.parquet имеет размерность 33059 строк и 363 столбцов
# ====================================================================================================

# %% [markdown]
# ## Объединение данных

# %%
begin = '/content/drive/MyDrive/Alfa Hack. Concat data/public/salary_outflow_fl/train'
end = '/content/drive/MyDrive/AH. Parquet/public/salary_outflow_fl'

files = []
begin_data = os.listdir(begin)

for file in begin_data:
  path = begin + f"/{file}"
  data = pd.read_parquet(path)
  files.append(data)

# Объединяем данные
files = pd.concat(files, ignore_index=True)
# Сохраняем данные
files.to_parquet(end+"/salary_outflow_fl_train.parquet", index=False)

# %%
# Ссылка на объединенные данные
public = "/content/drive/MyDrive/AH. Parquet/public"
# Список файлов в папке
public_folders = os.listdir(public)
# Вывод информации о файлах:
for fold in public_folders:
  # Путь к тестовым файлам
  path_test = public + f"/{fold}"
  # Получаем список файлов во внутренней папке
  files = os.listdir(path_test)
  # Открываем файлы
  for data in files:
    # Создаем путь к файлу
    data_path = path_test + f'/{data}'
    # Открываем файл
    curent_file = pd.read_parquet(data_path)
    # Выводим информацию о файле
    print("Файл {} имеет размерность {} строк и {} столбцов".format(data, curent_file.shape[0], curent_file.shape[1]))
  # Выведем разделитель
  print("="*50+"\n")
# Out:
# Файл salary_outflow_fl_test.parquet имеет размерность 270293 строк и 502 столбцов
# Файл salary_outflow_fl_train.parquet имеет размерность 729707 строк и 503 столбцов
# ==================================================
#
# Файл rko_propensit_test.parquet имеет размерность 304751 строк и 502 столбцов
# Файл rko_propensit_train.parquet имеет размерность 695249 строк и 503 столбцов
# ==================================================
#
# Файл osago_affinity_test.parquet имеет размерность 392019 строк и 502 столбцов
# Файл osago_affinity_train.parquet имеет размерность 607981 строк и 503 столбцов
# ==================================================
#
# Файл acquire_outflow_ul_test.parquet имеет размерность 330581 строк и 363 столбцов
# Файл acquire_outflow_ul_train.parquet имеет размерность 669419 строк и 364 столбцов
# ==================================================

# %%
print(27029*10+3)

print(72970*10+7)

print()

print(69524*10+9)

print(30475*10+1)

print()

print(60798*10+1)

print(39201*10+9)

print()

print(66941*10+9)

print(33058*10+1)

print()
# Out:
# 270293
# 729707
#
# 695249
# 304751
#
# 607981
# 392019
#
# 669419
# 330581

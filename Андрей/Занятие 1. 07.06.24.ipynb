# %% [markdown]
# # Знакомство с Google Colab

# %% [markdown]
# <img src="https://media.licdn.com/dms/image/D5612AQFzgboNy7BxHg/article-cover_image-shrink_600_2000/0/1696692478232?e=2147483647&v=beta&t=agwXAvJJa222qxW49Cq1cME1X4qLaZ2Rjph4EN1g25c">
#
#
#
# Google Colab — это бесплатная среда для разработки и выполнения программного кода в облаке. Google Colab соединяется с аккаунтом Google и диском Google Drive.
#
# Среда поддерживает работу с текстом в формате языка Markdown. Также среда Colab поддерживает работу с кодом на Python, а также синхронизацию в GitHub

# %% [markdown]
# Colab поддерживает добавление текста, с помощью кнопки __текст__, а также создание поля кода с помощью кнопки __код__

# %%
# Пример кода на Python
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# Запуск кода возможен с помощью кнопки запуска в левой части блока кода.
#
# Также возможно создать копию Colab на свой диск, выбрав __Файл->Создать копию на Диске__

# %% [markdown]
# Помимо этого возможно добавить файлы для работы с ними в файле Colab. Для этого нужно выбрать изображение папки в левой части меню, после чего откроется возможность добавить файл, получить информацию с облака Google, обновить репозиторий файлов.

# %% [markdown]
# Научимся импортировать файлы через Google Drive в Google Colab, для этого выполним нижеследующий код

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# После выполнения кода нужно выполнить следующие шаги:

# %% [markdown]
# 1. Подключиться к диску
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Выбрать аккаунт для фото
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Подтвердить вход в аккаунт
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# После выполнения кода, в нашей директории появится папка __drive__

# %% [markdown]
# При открытии ее с помощью нажатия на символ аналогичный символу плей, мы можем выбрать __MyDrive__ внутри которого будут находиться все файлы диска. При открытии диска мы сможем выбрать файл и скопировать путь к нему для работы.

# %% [markdown]
# # Язык Markdown в Colab

# %% [markdown]
# Для начала поговорим о том, что такое Markdown
#
# __Markdown__ — облегчённый язык разметки, созданный с целью обозначения форматирования в простом тексте, с максимальным сохранением его читаемости человеком, и пригодный для машинного преобразования в языки для продвинутых публикаций.

# %% [markdown]
# Markdown поддерживает следующую разметку
#
# 1. Заголовки
#
# ```markdown
# # Заголовок 1
# ```
#
# # Заголовок 1
#
# ```markdown
# ## Заголовок 2
# ```
#
# ## Заголовок 2
#
# ```markdown
# ### Заголовок 3
# ```
#
# ### Заголовок 3
#
#
# ```markdown
# #### Заголовок 4
# ```
#
# #### Заголовок 4
#
# ```markdown
# ##### Заголовок 5
# ```
#
# ##### Заголовок 5
#
# ```markdown
# ###### Заголовок 6
# ```
#
# ###### Заголовок 6

# %% [markdown]
# 2. Форматирование текста и его выделение
#
# ```
# *это текст курсивом*
# ```
#
# *это текст курсивом*
#
# ```
# _и это текст курсивом_
# ```
#
# _и это текст курсивом_
#
# ```
# **это текст жирным**
# ```
#
# **это текст жирным**
#
# ```
# __и это текст жирным__
# ```
#
# __и это текст жирным__
#
# ```
# ~~зачеркнутый текст~~
#
# ~ добавляется на английской раскладке, при зажатии Shift+Ё
# ```
#
# ~~зачеркнутый текст~~
#
# ```
# ***Жирный текст курсивом***
# ```
#
# ***Жирный текст курсивом***
#
# ```
# *__И это жирный текст курсивом__*
# ```
#
# *__И это жирный текст курсивом__*
#
# ```
# **_И даже это жирный текст курсивом_**
# ```
#
# **_И даже это жирный текст курсивом_**

# %% [markdown]
# 3. Форматирование текста спец.символами, влияющими на выделение
#
# Допустим мы хотим выделить текст с помощью __ с двух сторон, однако это служебный символ и при использовании его, мы получим не тот результат, какой ожидали. Для экранирования символов используем символ \
#
#
# ```
# \_Не курсив\_
# ```
#
# \_Не курсив\_
#
# ```
# \#Не заголовок\#
# ```
#
# \#Не заголовок\#
#
# ```
# \*\*Не жирный\*\*
# ```
#
# \*\*Не жирный\*\*

# %% [markdown]
# 4. Специальное форматирование
#
# ```
#   ```название языка
#   Выделение блока кода ```
# ```
#
# ```python
# print('Hello world!')
# ```
#
# ```
# > Цитата
# ```
#
# > Цитата великого человека не всегда обязана присутствовать
#
# Выделение переменных, как в учебниках
# ```
# $$alpha$$
# ```
#
# $$alpha$$
#
# #### Списки
#
# ```
# Нумерованный список
# 1. Мясо
# 2. Молоко
# 3. Хлеб
# 4. Кефир
# ```
#
# Нумерованный список
# 1. Мясо
# 2. Молоко
# 3. Хлеб
# 4. Кефир
#
# ```
# Ненумерованный список
# * Мясо
# * Молоко
# * Хлеб
# * Кефир
# ```
#
# Ненумерованный список
# * Мясо
# * Молоко
# * Хлеб
# * Кефир

# %% [markdown]
# 5. Добавление ссылок, картинок и эмодзи
#
# ```
# [Текст ссылки](URL_ссылки)
# ```
#
# [Colab Google](https://colab.google/)
#
# ```
# ![Необязательный текст картинки](URL_ссылки_на_изображение)
# ```
#
# ![Apple](https://frutsnab.ru/wa-data/public/shop/products/17/00/17/images/33/33.518x0@2x.jpg)
#
# ```
# :emoji_name
# ```
#
# \* работает не во всех редакторах
#
# Ссылка на все доступные эмоджи с названием:
# [WebFx](https://www.webfx.com/tools/emoji-cheat-sheet/)

# %%
name = input('Введите ваше имя: ')
recipients_name = input('Введите имя получателя поздравления: ')
wishes1 = input('Введите 1-ое пожелание для получателя: ')
wishes2 = input('Введите 2-ое пожелание для получателя: ')
wishes3 = input('Введите 3-ье пожелание для получателя: ')
wishes4 = input('Введите 4-ое пожелание для получателя: ')
bad_wishes = input('Напишите то, чего вы желаете избежать поздравителю: ')

print(f'''
От всей души поздравляю тебя, {recipients_name}, с Днем Рождения! Хочется пожелать тебе {wishes1}, также {wishes2}, и конечно же, столь нужного всем в последнее время
{wishes3}. Пусть следующий год твоей жизни принесет тебе только {wishes4}, а также поможет избежать {bad_wishes}.
С наилучшими пожланиями, в твой День Рождения - {name}!
''')
# Out:
# Введите ваше имя: Артур
# Введите имя получателя поздравления: Людмила
# Введите 1-ое пожелание для получателя: здоровья
# Введите 2-ое пожелание для получателя: успехов в учебе
# Введите 3-ье пожелание для получателя: новых умений в программировании
# Введите 4-ое пожелание для получателя: радость
# Напишите то, чего вы желаете избежать поздравителю: неприятных и печальных ситуаций
#
# От всей души поздравляю тебя, Людмила, с Днем Рождения! Хочется пожелать тебе здоровья, также успехов в учебе, и конечно же, столь нужного всем в последнее время
# новых умений в программировании. Пусть следующий год твоей жизни принесет тебе только радость, а также поможет избежать неприятных и печальных ситуаций.
# С наилучшими пожланиями, в твой День Рождения - Артур!

# %%
name = input('Введите ваше имя: ')
a, b, c = [int(input()) for _ in range(3)]
print(f'Дорогой/-ая, {name}, я поздравляю тебя с отличным результатом на экзаменах. \
{a} баллов - отличный результат по математике, {b} - отличный результат по информатике и наконец, прекрасный результат по русскому языку - {c} баллов!')
# Out:
# Введите ваше имя: Людмила
# 5
# 5
# 5
# Дорогой/-ая, Людмила, я поздравляю тебя с отличным результатом на экзаменах. 5 баллов - отличный результат по математике, 5 - отличный результат по информатике и наконец, прекрасный результат по русскому языку - 5 баллов!

# %%
count = int(input('Введите количество купленных товаров: '))
packets = int(input('Введите число нужных вам пакетов: '))
print(
f'''
Вы купили {count} товара/-ов и {packets} пакета/-ов. На сумму {count*99} рублей и {packets} рублей соответственно.
Общая стоимость вашей покупки составялет {count*99 + packets} рублей.
''')
# Out:
# Введите количество купленных товаров: 10
# Введите число нужных вам пакетов: 10
#
# Вы купили 10 товара/-ов и 10 пакета/-ов. На сумму 990 рублей и 10 рублей соответственно.
# Общая стоимость вашей покупки составялет 1000 рублей.

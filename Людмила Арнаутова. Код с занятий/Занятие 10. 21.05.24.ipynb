# %%
print('ac' > 'abcef')
# Out:
# True

# %% [markdown]
# a - 1, b - 2, c - 3, d - 4, e - 5, f - 6, g, h, i, j
#
# 13000
# 12356

# %%
count = int(input('Введите количество купленных товаров: '))
price = count * 99

if 500 <= price < 1500:
  price = price*(100-5)/100
  print(f'Стоимость вашей покупки за вычетом скидки равна {price}')

if 1500 <= price < 5000:
  price = price*(100-10)/100
  print(f'Стоимость вашей покупки за вычетом скидки равна {price}')

if 5000 <= price < 10000:
  price = price*(100-20)/100
  print(f'Стоимость вашей покупки за вычетом скидки равна {price}')

if 10000 <= price:
  price = price*(100-25)/100
  print(f'Стоимость вашей покупки за вычетом скидки равна {price}')
# Out:
# Введите количество купленных товаров: 200
# Стоимость вашей покупки за вычетом скидки равна 14850.0

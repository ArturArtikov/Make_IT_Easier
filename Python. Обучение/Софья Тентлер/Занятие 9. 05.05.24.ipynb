# %%
name = input('Введите ваше имя: ')
print(f'Здравствуйте, {name}! Это программа по выбору фильма на основе жанра и настроения')
# Комедия, Ужасы, Фантастика, Триллеры, Боевики, Мелодрамы, Приключения, Драмы, Вестерны
films = {'Комедия': ['Один дома', 'Маска', 'Друзья'], 'Ужасы': ['Оно', 'Очень странные дела', 'Грим'], 'Фантастика': ['Дюна', 'Стражи Галактики', 'Звездные войны'], \
         'Триллеры': ['Остров проклятых', 'Области тьмы', 'Престиж'], 'Боевики': ['Дедпул', 'Леон', 'Гнев человечский'], 'Мелодрамы': ['Мой Демон',  'Когда я лечу к тебе', 'Истинная красота'], \
         'Приключения': ['Пираты Карибского моря', 'Валериан и город тысячи планет', 'Назад в будущее'], 'Драмы': ['Хатико', 'Зеленая миля', 'Мастер и Маргарита'], \
         'Вестерны': ['Джанго освобожденный', 'Строго на запад', 'Старый Генри']}
genre = input('Введите пожалуйста жанр: ').capitalize() # КОМЕДИЯ - Комедия, боевики - Боевики

print('\nСписок фильмов по вашему жанру:', *films[genre], sep='\n')
# Out:
# Введите ваше имя: Артур
# Здравствуйте, Артур! Это программа по выбору фильма на основе жанра и настроения
# Введите пожалуйста жанр: ТРИЛЛЕРЫ
#
#  Список фильмов по вашему жанру:
# Остров проклятых
# Области тьмы
# Престиж

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Rumatica/Август/август2/Заполненные типы на русском/Заполненные категории на русском.csv')
data2 = pd.read_csv('/content/drive/MyDrive/Rumatica/Август/август2/product_random description_type_multi_lang.csv', sep=';')

# %%
data2['product_type_ru_old'] = data2['product_type_ru']

# %%
data1.head()
# Out:
#                    product_type_ru              product_type_en  \
# 0  Защитный выключатель блокировки  Guard locking safety switch
# 1  Защитный выключатель блокировки  Guard locking safety switch
# 2  Защитный выключатель блокировки  Guard locking safety switch
# 3                             Ключ  Switches with guard locking
# 4                             Ключ  Switches with guard locking
#
#   product_type_de product_category  \
# 0               -    Переключатели
# 1               -    Переключатели
# 2               -    Переключатели
# 3               -    Переключатели
# 4               -    Переключатели
#
#                                                photo  \
# 0  https://www.bernstein.eu/fileadmin/img/produkt...
# 1  https://www.bernstein.eu/fileadmin/img/produkt...
# 2  https://www.bernstein.eu/fileadmin/img/produkt...
# 3  https://www.bernstein.eu/fileadmin/_migrated/p...
# 4  https://www.bernstein.eu/fileadmin/_migrated/p...
#
# ...

# %%
data1 = pd.concat([data2['product_type_ru_old'], data1], axis=1)
data1.head()
# Out:
#                product_type_ru_old                  product_type_ru  \
# 0  Защитный выключатель блокировки  Защитный выключатель блокировки
# 1  Защитный выключатель блокировки  Защитный выключатель блокировки
# 2  Защитный выключатель блокировки  Защитный выключатель блокировки
# 3                              NaN                             Ключ
# 4                              NaN                             Ключ
#
#                product_type_en product_type_de product_category  \
# 0  Guard locking safety switch               -    Переключатели
# 1  Guard locking safety switch               -    Переключатели
# 2  Guard locking safety switch               -    Переключатели
# 3  Switches with guard locking               -    Переключатели
# 4  Switches with guard locking               -    Переключатели
#
#                                                photo  \
# 0  https://www.bernstein.eu/fileadmin/img/produkt...
# 1  https://www.bernstein.eu/fileadmin/img/produkt...
# ...

# %%
data1.to_csv('Сравнение старой и новой версии ключевиков.csv', index=False, sep=';')

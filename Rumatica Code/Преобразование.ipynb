# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/RMTC/Август/август2/Записи с показателем наличия ключевых слов в фото.csv')
data.head()
# Out:
# <ipython-input-3-819a58587056>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/drive/MyDrive/RMTC/Август/август2/Записи с показателем наличия ключевых слов в фото.csv')
#        id brand_name     article      product_category photo  \
# 0  118114  Bernstein  6116169016         Переключатели   NaN
# 1  118119  Bernstein  6016869056         Переключатели   NaN
# 2  118384  Bernstein  6088103001  Концевые выключатели   NaN
# 3  118385  Bernstein  6088117007  Концевые выключатели   NaN
# 4  118390  Bernstein  6088153002  Концевые выключатели   NaN
#
#                                     description_und  is_key
# 0                       Limit switch\nSKC-A1Z F30 M   False
# 1                    SKI-A2Z M3                   A   False
# 2  Positionsschalter TI2-U1Z W,Endschalter Ti2-U1ZW   False
# 3                Nachspann ti2-u1z riw,limit switch   False
# ...

# %%
data.drop('description_und', axis=1).to_excel('Записи с показателем наличия ключевых слов в фото.xlsx', index=False)

# %%
display(data[data['is_key'] == True]['photo'].iloc[3564])
# Out:
# 323437         schaltertechnik zuhaltungs bernstein slc new
# 323438         schaltertechnik zuhaltungs bernstein slc new
# 323439         schaltertechnik zuhaltungs bernstein slc new
# 323440    www.bernstein.eu fileadmin _migrated pics bern...
# 323441    www.bernstein.eu fileadmin _migrated pics bern...
#                                 ...
# 356955                        shop media smc tu bu_blue.jpg
# 356956                       shop media smc zp2 b fm mb.jpg
# 356957                      www.rittal.com imf jpg 78_2063
# 356958    www.contrinex.com cdn shop products DW AD 509 ...
# 356959    www.contrinex.com cdn shop products DW AD 621 ...
# Name: photo, Length: 33282, dtype: object

# %%
description = pd.read_csv('/content/drive/MyDrive/RMTC/Август/1-7 августа/product_random_description.csv', sep=';')
description.head()
# Out:
#        id brand_name     article            product_name  \
# 0  118048  Bernstein  6018200002      SLC-M-024-11/11-R4
# 1  118053  Bernstein  6018200007      SLC-F-024-20/20-R4
# 2  118054  Bernstein  6018200008      SLC-F-024-11/20-R4
# 3  118074  Bernstein  6018119045  SLK-F-UC-55-R1-A0-L0-0
# 4  118076  Bernstein  6018119047  SLK-M-UC-55-R0-A0-L0-0
#
#                       product_type product_category  \
# 0  Защитный выключатель блокировки    Переключатели
# 1  Защитный выключатель блокировки    Переключатели
# 2  Защитный выключатель блокировки    Переключатели
# 3                              NaN    Переключатели
# 4                              NaN    Переключатели
#
#                                                photo famaga_photo  \
# 0  https://www.bernstein.eu/fileadmin/img/produkt...          NaN
# 1  https://www.bernstein.eu/fileadmin/img/produkt...          NaN
# 2  https://www.bernstein.eu/fileadmin/img/produkt...          NaN
# ...

# %%
data['product_category'].value_counts(dropna=False)
# Out:
# product_category
# NaN                                                      346802
# Коннекторы для передачи данных                              909
# Инкрементальные энкодеры                                    759
# Реле безопасности                                           581
# Пневмоцилиндры                                              503
#                                                           ...
# Аксессуары для реле безопасности                              1
# Частотомеры                                                   1
# Металлические профили, Профили для модульных структур         1
# Ручки                                                         1
# Пружины                                                       1
# Name: count, Length: 305, dtype: int64

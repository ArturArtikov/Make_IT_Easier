# %% [markdown]
# # Модули random, time и math

# %% [markdown]
# Документация по библиотеке __math__ на русском: [документация](https://pythonworld.ru/moduli/modul-math.html)
#
# Документация по библиотеке __time__ на русском: [документация](https://pythonworld.ru/moduli/modul-time.html)
#
# Документация по библиотеке __random__ на русском: [документация](https://pythonworld.ru/moduli/modul-random.html)

# %%
import random
import time

# %%
random_integer = random.randint(1, 10)
print(random_integer)
# Out:
# 6

# %%
a = random.randrange(10, 100, 2)
print(a)
# Out:
# 44

# %%
print('Приветсвуем вас в нашей программе!')
time.sleep(5)
print('Выберите интересующий вас пункт меню')
# Out:
# Приветсвуем вас в нашей программе!
# Выберите интересующий вас пункт меню

# %%
print(f'Текущее время: {time.time()}')
# Out:
# Текущее время: 1717345584.6998575

# %%
start1 = time.time()

a = 20
while a > 10:
  a -= 1
print('Закончили')

end1 = time.time()


start2 = time.time()

b = 20
for i in range(10, 21):
  c = i * 2
print('Закончили')

end2 = time.time()
# Out:
# Закончили
# Закончили

# %%
print(f'Время работы первой программы - {end1-start1}, а второй - {end2-start2}')
# Out:
# Время работы первой программы - 0.0021219253540039062, а второй - 0.0008285045623779297

# %%
import math

# %%
number = 10.34

print(math.ceil(number)) # округляет до ближайшего большего значения в целое число
# Out:
# 11

# %%
print(math.floor(10.9)) # возвращает округленное вниз
# Out:
# 10

# %%
print(math.fabs(-15.90)) # возвращает модуль числа
# Out:
# 15.9

# %%
print(math.factorial(5)) # возвращает факториал числа
# Out:
# 120

# %%
print(math.pi, math.e) # значения чисел Пи и Эйлера
# Out:
# 3.141592653589793 2.718281828459045

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
files = os.listdir('/content/drive/MyDrive/Excel для Элины')

# %%
for file in files:
  if file.endswith('.xlsx'):
    continue
  else:
    files.remove(file)

print('Итоговый список файлов {}'.format(files))
print('Число таких файлов - {}'.format(len(files)))
# Out:
# Итоговый список файлов ['01.03.2023.xlsx', '06.03.2024.xlsx', '14.03.2024.xlsx', '09.02.2024.xlsx', '06.02.2024.xlsx', '07.02.2024.xlsx', '08.02.2024.xlsx', '11.02.2024.xlsx', '12.02.2024.xlsx', '13.02.2023.xlsx', '14.02.2024.xlsx', '19.02.2024.xlsx', '22.02.2024.xlsx', '25.02.2024.xlsx', '25.12.2024.xlsx', '26.01.2024.xlsx', '26.02.2024.xlsx', '27.01.2024.xlsx', '28.01.2024.xlsx', '28.02.2024.xlsx', '29.01.2024.xlsx', '11.03.2024.xlsx', '24.01.2024.xlsx', '27.02.2024.xlsx']
# Число таких файлов - 24

# %%
path1 = '/content/drive/MyDrive/Excel для Элины'+'/'+files[0]
path1 = path1.replace('\t', ' ')
data = pd.read_excel(path1, sheet_name=0)
display(data)
# Out:
#       Source Статус экспорта Original Line           Original Equipment  \
# 0        OPC        Not Sent            GM                        Влф№2
# 1        OPC        Not Sent           RLL  Кнвр под- ый "ГСЬ"-1 (Inln)
# 2        OPC        Not Sent            GM                    Инлн пдча
# 3        OPC        Not Sent            GM                        Влф№1
# 4        OPC        Not Sent            GM                    Инлн пдча
# ..       ...             ...           ...                          ...
# 806  UNKNOWN        Not Sent           RLL             Сборн. кнвр (БШ)
# 807  UNKNOWN        Not Sent            ND           Автгрв + Вар клнка
# 808  UNKNOWN        Not Sent            ND                         CFA2
# 809      OPC        Not Sent           RLL  Кнвр под- ый "ГСЬ"-1 (Inln)
# 810  UNKNOWN  Auto Discarded            ND     Avtgrv +Вар аппрт BSCH#3
#
#         Оригинальная категория Оригинальная подкатегория  \
# ...

# %%
data['current_date'] = files[0].replace('.xlsx', '')

# %%
files = files[1:]

# %%
print(len(files))
# Out:
# 23

# %%
for file in files:
  path = '/content/drive/MyDrive/Excel для Элины'+'/'+file
  path = path.replace('\t', ' ')
  new_data = pd.read_excel(path, sheet_name=0)
  new_data['current_date'] = file.replace('.xlsx', '')
  data = pd.concat([data, new_data], ignore_index=True)

# %%
info = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18943 entries, 0 to 18942
# Data columns (total 49 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Source                                   18943 non-null  object
#  1   Статус экспорта                          18943 non-null  object
#  2   Original Line                            18943 non-null  object
#  3   Original Equipment                       18943 non-null  object
#  4   Оригинальная категория                   18943 non-null  object
#  5   Оригинальная подкатегория                18943 non-null  object
#  6   Original Sub Category (Full Path)        18943 non-null  object
#  7   Original Sub Category (Minor Stops)      18943 non-null  object
#  8   Оригинальная причина                     18943 non-null  object
#  9   Original Reason (Full Path)              18943 non-null  object
# ...

# %%
data.to_csv('out.csv')

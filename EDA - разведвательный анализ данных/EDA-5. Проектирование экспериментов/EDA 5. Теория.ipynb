# %% [markdown]
# # 1. Введение в модуль
#
# В ЭТОМ МОДУЛЕ МЫ УЗНАЕМ:
# * какую роль занимают эксперименты в проектах по машинному обучению;
# * что означает отслеживание экспериментов;
# * как пользоваться популярным инструментом для мониторинга проектов в ML.
#
# В ЭТОМ МОДУЛЕ МЫ НАУЧИМСЯ:
#
# * проектировать эксперименты и строить по ним выводы;
#
# * запускать платформу для трекинга и производить логирование экспериментов из Colab.

# %% [markdown]
# # 2. Введение в проектирование экспериментов
#
# Машинное обучение (ML) — это область компьютерных наук, которая использует алгоритмы для создания и обучения моделей для выполнения рутинных задач.
#
# Типичный подход к управлению проектами машинного обучения основан на проектировании моделей машинного обучения вручную. И обычно он представлен следующими этапами:
#
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/55016f8e2b093a5e8f2faa175f0638ed/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/dst-eda-6-1.png)
#
# Обученная модель может удовлетворить непосредственные потребности заказчика только на основе данных, которые ей были предоставлены, но в долгосрочной перспективе она может оказаться неэффективной, поскольку она не приспосабливается автоматически к изменениям в наборах данных.
#
# Точность модели (accuracy) машинного обучения определяется как процент правильных прогнозов для тестовых данных и рассчитывается путём деления количества правильных прогнозов на общее количество прогнозов. Обычно это определяющий фактор при оценке успеха проекта машинного обучения — чем выше точность, тем лучше работает модель машинного обучения.
#
# ![](https://lms-cdn.skillfactory.ru/assets/courseware/v1/51d97d83c89292c847920693528eaaa6/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/dst-eda-6-2.png)
#
# __КАК ДОБИТЬСЯ ЛУЧШЕЙ ТОЧНОСТИ МОДЕЛИ ML?__
#
# Возникает необходимость отслеживания экспериментов, то есть сохранения всей важной информации, связанной с каждым запускаемым экспериментом, например сохранение параметров запуска, влияющих на производительность модели. Выполнять эту задачу вручную обременительно, поэтому имеет смысл поставить для процесса автоматизированную инфраструктуру — пайплайн (pipeline) машинного обучения.
#
# Пайплайном (pipeline) в ML называется способ систематизации и автоматизации рабочего процесса, необходимого для создания модели машинного обучения. Пайплайны состоят из нескольких последовательных шагов, которые выполняют всё — от извлечения и предварительной обработки данных до обучения и проверки моделей.
#
# Пайплайн машинного обучения состоит из следующих шагов:
# ![](https://lms-cdn.skillfactory.ru/assets/courseware/v1/39ebef88c19308deecbce2266474b48e/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/dst-eda-6-3.png)
#
# Этот рабочий процесс позволяет осуществлять непрерывную настройку существующих моделей наряду с постоянной оценкой производительности. Самым большим преимуществом этого процесса является то, что его можно автоматизировать с помощью доступных инструментов.
#
# Каждая история болезни характеризуется следующими признаками:
#
# * No_show — пациент не пришёл на приём;
# * Gender — пол пациента;
# * ScheduledDay — день, когда планируется встреча;
# * AppointmentDay — реальная дата встречи;
# * Age — возраст пациента;
# * Neighbourhood — район проживания каждого пациента;
# * Scholarship — получает ли пациент стипендию;
# …и несколько других признаков.

# %%
import pandas as pd
df = pd.read_csv('https://lms-cdn.skillfactory.ru/assets/courseware/v1/757324828c4c8e82141ee30b3a5e2022/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/KaggleV2-May-2016.csv.zip')

# %% [markdown]
# Основная цель проекта — выделить факторы, способствующие пропуску встреч с врачом. Однако это долгосрочная цель. Прежде чем копнуть глубже, необходимо попытаться ответить на следующие вопросы:
#
# Каково соотношение людей, которые пропускают встречи, к тем, кто этого не делает?
# Кто не появляется чаще — мужчины или женщины?
#
# 2. Для ответа на эти и другие подобные вопросы используется EDA.
#
# Найти соотношение людей, которые пропускают приёмы, к тем, кто этого не делает, можно с помощью гистограммы:

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))
df['No-show'].hist()
plt.title('Соотношение людей, которые пропускают приемы, к тем, кто этого не делает');

# %%
df['No-show'].value_counts(True)
# Out:
# No     0.798067
# Yes    0.201933
# Name: No-show, dtype: float64

# %% [markdown]
# Данный метод также может помочь оценить, кто не появляется чаще — мужчины или женщины:

# %%
df[df['No-show']=='Yes']['Gender'].value_counts(True)
# Out:
# F    0.653882
# M    0.346118
# Name: Gender, dtype: float64

# %% [markdown]
# Итак, мы видим, что людей, пропускающих приём, примерно 20 %.

# %% [markdown]
# 3. После того, как выполнен разведывательный анализ данных, переходим к предобработке данных. Некоторые столбцы, например ‘Gender’ и ‘Neighbourhood’, представлены в текстовом виде, а модели машинного обучения работают с числовыми признаками. Необходимо закодировать такие данные. Для one-hot кодировки можно воспользоваться методом get_dummies() библиотеки pandas:

# %%
categorical_columns_names = ['Gender', 'Neighbourhood']
encoded_columns = pd.get_dummies(df, columns = categorical_columns_names)

# %% [markdown]
# 4. После этих этапов можно переходить к созданию предсказания, придёт ли пациент на приём, обучению и оптимизации модели, а также выделению наиболее важных признаков, способствующих высокой производительности модели. Об этом вы узнаете в будущих модулях!
#
# Модели машинного обучения могут рассматриваться как чёрный ящик: нечто, куда мы кладём свои данные и получаем предсказание. Не всегда результаты прогнозов легко интерпретируемы. Обычно существует трэйд-офф между качеством модели и её интерпретируемостью: чем сложнее модель, тем выше, но менее очевиден её результат.
#
# Как мы уже выяснили, в реальных проектах может понадобиться не один эксперимент для улучшения производительности модели. Появляется необходимость сохранения всей важной информации, связанной с каждым запускаемым экспериментом. Как сохранять такую информацию, вы узнаете в следующем юните.

# %% [markdown]
# # 3. Логирование экспериментов
#
# Сравнение результатов ML-экспериментов становится весьма затруднительным процессом, потому что необходимо иметь записи всех проводимых ранее экспериментов. Например, если во время EDA-задачи предсказания спроса на лекарство изменяются данные, то каждый раз выводить на экран новую визуализацию неудобно.
#
# Логирование решает эту проблему! Даже если информация изменится с запуском нового эксперимента, всё будет зафиксировано в логе.
#
# Лог (log) — это специальный журнал, в котором хранится информация о состоянии работы программы. Логирование (ведение журнала) обеспечивает отслеживание событий, происходящих во время работы программы, и может выводить эти события в отдельный файл, чтобы вы могли отслеживать, что происходит во время выполнения кода.
#
# Для логирования в Python используется модуль logging. Он используется большинством сторонних библиотек Python, поэтому вы можете интегрировать свои логи с сообщениями из этих библиотек для создания единого журнала логов приложения. Данный модуль импортируется как другие библиотеки:

# %%
import logging

# %% [markdown]
# Прежде чем приступить к логированию, необходимо установить базовые настройки:
#
# * уровень;
# * обработчик (хендлер);
# * формат логирования.
#
# __НАСТРОЙКА УРОВНЯ ЛОГИРОВАНИЯ__
#
# С импортированным модулем logging вы можете использовать так называемый «logger» для логирования сообщений, которые вы хотите видеть (вместо вывода их на экран командой print()).
#
# По умолчанию существует пять стандартных уровней логирования, указывающих на важность событий:
#
# * отладка;
# * информация;
# * предупреждение;
# * ошибка;
# * критический.
#
# Самый низкий уровень из данных — не установлен, а самый высокий уровень является критическим. Установив уровень логирования, можно записать сообщение специально для этого уровня в определённый файл журнала. Возле сообщения будет указан его уровень.

# %%
import logging
logging.debug('This is a debug message')
logging.info('This is an informational message')
logging.warning('This message is a warning')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This message is a warning
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# Здесь мы дали команду залогировать пять сообщений. Вывод команд показывает уровень важности перед каждым сообщением (WARNING/ERROR/CRITICAL). root — имя логгера по умолчанию.
#
# Обратите внимание, что сообщения debug() и info() не были отображены. Это связано с тем, что по умолчанию модуль ведения журнала регистрирует сообщения только с уровнем ПРЕДУПРЕЖДЕНИЕ (WARNING) или выше. Вы можете изменить это, сконфигурировав модуль logging для регистрации событий всех уровней, то есть установив уровень на ОТЛАДКУ (DEBUG).
#
# Чтобы сделать это, нужно сначала сбросить настройки библиотеки logging, перезапустив наш ноутбук. В VS Code это делается с помощью кнопки перезапуска:
#
# ![](https://lms-cdn.skillfactory.ru/assets/courseware/v1/cfb3c3c29a8e3be5c9ddd17a986106f5/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/dst-eda-6-extra-02.png)
#
# Другой вариант сбросить настройки logging — воспользоваться функцией reload() из вспомогательной системной библиотеки importlib:

# %%
from importlib import reload
import logging
reload(logging)
logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# Далее, когда настройки логирования сброшены, нам необходимо перед выводом сообщений, сразу после импорта, изменить конфигурацию логгера.

# %% [markdown]
# Мы настроили уровень ведения журнала DEBUG. Это означает, что теперь будут отслеживаться только сообщения этого уровня (DEBUG) и выше. В результате выполнения кода логирования мы должны получить следующие сообщения:

# %%
logging.debug('This is a debug message')
logging.info('This is an informational message')
logging.warning('This message is a warning')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is an informational message
# WARNING:root:This message is a warning
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# Как видно из результата выполнения кода, теперь в консоль выводятся лог-сообщения всех уровней.
#
# Однако, как вы понимаете, логирование в консоль ничем не лучше простого вывода сообщений с помощью функции print(). Обычно логирование производится в специальные лог-файлы, для этого используются обработчики (хендлеры) логов. Давайте рассмотрим пример логирования в файл.
#
# __УСТАНОВКА ОБРАБОТЧИКА ЛОГИРОВАНИЯ__
#
# Функция обработчиков ведения журналов состоит в том, чтобы отображать записи/сообщения журнала на любом выходе, который вы выберете. То есть вы можете выбрать, отображать ли ваш лог в виде файла, HTTP-страницы или даже отправить лог на электронную почту через SMTP.
#
# Более того, у созданного вами logger может быть несколько обработчиков, а это значит, что вы можете настроить его на сохранение в файл журнала, а также на отправку по email одновременно. Подробнее ознакомиться с видами хендлеров можно [здесь](https://digitology.tech/docs/python_3/library/logging.handlers.html).
#
# Обработчики являются классами модуля logging. Нам понадобится обработчик FileHandler, который возьмёт запись/сообщение журнала и добавит его в файл журнала log_file.log:

# %%
logging.FileHandler('log_file.log')
# Out:
# <FileHandler /content/log_file.log (NOTSET)>

# %% [markdown]
# __УСТАНОВКА ФОРМАТА ЛОГИРОВАНИЯ__
#
# Как мы уже сказали, типичный формат лога выглядит так: уровень: имя: сообщение. Однако его можно изменить.
#
# Существуют различные способы форматирования записи журнала. Вы можете включить дату, время и уровень ведения журнала в свой формат, чтобы знать, когда журнал был отправлен и на каком уровне. В приведённом ниже примере показано, как можно настроить формат записей журнала. Так как мы вновь переопределяем настройки библиотеки logging, то не забудем сбросить конфигурацию.

# %%
from importlib import reload
import logging
reload(logging)

logging.basicConfig(
    format="%(levelname)s: %(asctime)s: %(message)s",
    level=logging.DEBUG
)
logging.info('Check')
# Out:
# INFO: 2023-10-28 22:55:38,739: Check

# %% [markdown]
# Здесь формат записей журнала включает дату, время, уровень ведения журнала и само сообщение. Таким образом, вы можете изменять как формат лога, так и формат вывода. Добавление времени сообщения существенно облегчает работу — становится легко отследить, когда было получено сообщение.

# %% [markdown]
# Создадим новый ipynb файл, в котором будем выполнять логирование.
# Создадим функцию get_logger() для генерации лог-файла и записи в него информации.

# %%
import os.path

def get_logger(path, file):
  """[Создает лог-файл для логирования в него]
  Аргументы:
      path {string} -- путь к директории
      file {string} -- имя файла
   Возвращает:
      [obj] -- [логер]
  """
  # проверяем существует ли файл
  log_file = os.path.join(path, file)

  # если нет файла, то создаем его
  if not os.path.isfile(log_file):
    open(log_file, "w+").close()

  # поменяем формат логирования
  file_logging_format = "%(levelname)s: %(asctime)s: %(message)s"

  # конфигурируем лог-файл
  logging.basicConfig(level=logging.INFO,
                      format = file_logging_format)
  logger = logging.getLogger()

  # создадим хэнлдер для записи лога в файл
  handler = logging.FileHandler(log_file)

  # создадим формат логирования, используя file_logging_format
  formatter = logging.Formatter(file_logging_format)
  handler.setFormatter(formatter)

  # добавим хэндлер лог-файлу
  logger.addHandler(handler)
  return logger

# %% [markdown]
# Итак, get_logger принимает на вход папку, в которой вы хотите хранить файл лога и имя файла. Функция нацелена на создание информационных сообщений и записи их в лог-файл.
#
# Для удобства лог-файлы хранят в отдельной директории. Новую папку можно создать с помощью команды mkdir:

# %%
# !mkdir logs

# %% [markdown]
# Создадим лог-файл и запишем туда информацию о датасете.

# %%
# создаем лог-файл
logger = get_logger(path="logs/", file="data.logs")

logger.info("Data")

logger.info("Data shape {}".format(df.shape))

logger.info("Percentage of women: {}".format(df[df['No-show']=='Yes']['Gender'].value_counts(True)[0]))

logger.info("Percentage of men: {}".format(df[df['No-show']=='Yes']['Gender'].value_counts(True)[1]))
# Out:
# INFO: 2023-10-28 23:09:54,786: Data
# INFO: 2023-10-28 23:09:54,788: Data shape (110527, 14)
# INFO: 2023-10-28 23:09:54,816: Percentage of women: 0.653882342398853
# INFO: 2023-10-28 23:09:54,833: Percentage of men: 0.346117657601147

# %% [markdown]
# Отлично! Мы зафиксировали информацию о датасете в лог-файл. Такой файл отражает сведения о том, что всё работает в штатном режиме (то есть просто ежедневный мониторинг программы) или что произошла какая-то ошибка, на которую нужно максимально срочно отреагировать и устранить. Например, мы можем проверять форму данных, и, если форма не соответствует необходимой, логировать ошибку:

# %%
if df.shape != (110526, 14):
  logger.error('Data shape is incorrect!')
# Out:
# ERROR: 2023-10-28 23:11:00,815: Data shape is incorrect!

# %% [markdown]
# В следующем юните вы познакомитесь с платформой, которая позволяет не только логировать информацию об эксперименте, но и с лёгкостью сравнивать эксперименты между собой, а также работать над ними в команде!

# %% [markdown]
# # 4. Знакомство с Comet.ml
#
# Comet.ml — это онлайн-платформа, позволяющая отслеживать эксперименты. Основное преимущество Comet состоит в том, что с её помощью можно легко построить панель отчётности и систему мониторинга.
#
# Comet предоставляет следующие возможности:
#
# * сравнивать эксперименты с точки зрения метрик, параметров и так далее;
# * следить за моделью от создания до вывода в продакшен;
# * делиться своим проектом с другими людьми, которые в режиме реального времени будут следить за результатами;
# * строить отчёты исходя из результатов эксперимента;
# * оставить проект приватным или сделать его общедоступным.
#
# Для начала работы с платформой [Comet.ml](https://www.comet.ml/site/) необходимо зарегистрировать бесплатную учётную запись. После этого вы сможете создавать как публичные, так и приватные проекты.

# %% [markdown]
# После создания проекта появится пустая доска, на которую можно добавить эксперименты, нажав на кнопку +Add.
#
# ![](https://lms-cdn.skillfactory.ru/assets/courseware/v1/0d23dd53c20f59c030b67e1e64ddc518/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block/dst-eda-6-17.png)
#
# ```python
# from comet_ml import Experiment
#
# # Создайте эксперимент с помощью вашего API ключа
# experiment = Experiment(
#     api_key="УКАЖИТЕ ЗДЕСЬ СВОЙ КЛЮЧ API",
#     project_name="medical-appointment",
#     workspace="УКАЖИТЕ ЗДЕСЬ ИМЯ СВОЕЙ УЧЕТНОЙ ЗАПИСИ",
# )
# ```

# %%
! pip install comet_ml
# Out:
# Collecting comet_ml
#   Downloading comet_ml-3.35.1-py3-none-any.whl (584 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.0/584.0 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.19.1)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 21.6 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.8.0 (from comet_ml)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.31.0)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.1.0 (from comet_ml)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 15.6 MB/s eta 0:00:00
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.0.7)
# Collecting websocket-client<1.4.0,>=0.55.0 (from comet_ml)
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.14.1)
# Collecting wurlitzer>=1.0.2 (from comet_ml)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting everett[ini]<3.2.0,>=1.0.1 (from comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.21.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.6.0)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Installing collected packages: everett, wurlitzer, websocket-client, simplejson, sentry-sdk, semantic-version, python-box, dulwich, configobj, requests-toolbelt, comet_ml
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# Successfully installed comet_ml-3.35.1 configobj-5.0.8 dulwich-0.21.6 everett-3.1.0 python-box-6.1.0 requests-toolbelt-1.0.0 semantic-version-2.10.0 sentry-sdk-1.32.0 simplejson-3.19.2 websocket-client-1.3.3 wurlitzer-3.0.3

# %%
from comet_ml import Experiment

# Создайте эксперимент с помощью вашего API ключа
experiment = Experiment(
    api_key="gTxd8jP18ef7MBtM4AlDxvxuj",
    project_name="medical-appointment",
    workspace="arturartikov",
)
# Out:
# DEBUG: 2023-10-28 23:19:51,432: [Tracing] Create new propagation context: {'trace_id': 'bd81eb20c0b5432584e0e86d7f85cbac', 'span_id': 'b25eec40098d73b1', 'parent_span_id': None, 'dynamic_sampling_context': None}
# DEBUG: 2023-10-28 23:19:51,728: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,730: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,737: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,742: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,743: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,746: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,747: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,749: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,750: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,753: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,755: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,757: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,758: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,760: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,761: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,762: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,764: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,765: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,767: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,768: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,770: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,771: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,773: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,774: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,776: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,777: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,778: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,780: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,781: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,783: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,784: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,786: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,787: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,789: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,790: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,792: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,793: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,794: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,796: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,797: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,799: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,800: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,801: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,803: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,804: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,806: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,807: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,809: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,810: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,812: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,813: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,814: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,816: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,817: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,822: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,824: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,825: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,827: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,828: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,829: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,831: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,832: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,833: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,839: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,841: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,842: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,844: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,845: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,846: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,848: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,849: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,850: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,853: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,855: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,856: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,857: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,858: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,859: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,861: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,862: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,863: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,865: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,868: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,869: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,870: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,871: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,872: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,873: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,875: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,876: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,882: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,884: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,886: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,887: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,888: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,889: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,890: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,891: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,892: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,894: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,896: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,897: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,899: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,900: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,902: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,905: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,907: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,908: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,910: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,912: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,913: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,914: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,916: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,917: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,919: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,921: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,922: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,924: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,926: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,927: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,928: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,929: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,931: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,932: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,938: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,940: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,942: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,943: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,946: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,948: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,950: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,953: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,956: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,958: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,959: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,961: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,963: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,964: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,965: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,967: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,968: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,969: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,971: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,972: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:51,977: No INI file found: []
# DEBUG: 2023-10-28 23:19:51,981: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:51,986: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:51,988: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:51,994: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:51,995: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,996: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:51,998: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,001: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,008: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,013: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,015: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,021: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,022: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,023: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,024: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,027: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,034: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,036: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,037: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,038: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,040: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,041: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,043: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,044: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,045: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,047: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,048: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,049: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,051: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,052: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,053: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,055: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,056: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,057: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,058: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,060: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,061: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,062: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,064: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,065: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,066: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,067: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,069: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,070: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,075: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,076: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,078: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,080: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,081: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,082: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,083: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,085: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,086: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,087: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,093: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,095: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,099: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,101: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,102: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,103: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,109: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,110: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,112: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,113: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,119: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,120: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,121: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,127: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,128: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,129: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,160: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,163: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,166: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,171: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,178: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,180: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,183: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,187: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,189: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,193: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,215: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,217: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,219: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,220: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,221: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,222: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,223: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,225: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,226: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,227: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,228: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,229: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,230: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,231: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,232: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,234: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,235: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,236: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,237: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,238: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,239: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,241: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,242: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,243: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,244: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,245: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,246: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,250: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,252: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,256: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,259: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,262: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,263: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,265: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,266: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,271: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,272: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,273: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,277: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,279: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,280: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,292: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,295: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,296: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,298: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,299: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,302: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,303: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,308: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,310: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,311: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,316: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,317: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,323: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,324: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,325: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,326: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,332: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,333: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,334: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,335: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,336: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,341: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,343: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,344: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,345: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,350: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,352: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,353: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,356: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,357: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,361: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,366: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,368: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,369: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,370: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,375: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,378: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,380: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,385: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,386: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,391: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,392: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,393: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,398: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,400: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,401: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,404: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,405: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-10-28 23:19:52,406: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,410: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,413: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,414: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,418: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,421: Looking up key: console, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,423: Searching <ConfigOSEnv> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-10-28 23:19:52,426: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-10-28 23:19:52,430: Searching <ConfigDictEnv: {}> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-10-28 23:19:52,431: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,434: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,437: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,443: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,447: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,450: Looking up key: rich_output, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,453: Searching <ConfigOSEnv> for COMET_RICH_OUTPUT
# DEBUG: 2023-10-28 23:19:52,455: Searching <ConfigEnvFileEnv: None> for COMET_RICH_OUTPUT
# DEBUG: 2023-10-28 23:19:52,459: Searching <ConfigDictEnv: {}> for COMET_RICH_OUTPUT
# DEBUG: 2023-10-28 23:19:52,460: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,463: Looking up key: file, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,464: Searching <ConfigOSEnv> for COMET_LOGGING_FILE
# DEBUG: 2023-10-28 23:19:52,469: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE
# DEBUG: 2023-10-28 23:19:52,470: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE
# DEBUG: 2023-10-28 23:19:52,471: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,475: Looking up key: project_name, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,477: Searching <ConfigOSEnv> for COMET_PROJECT_NAME
# DEBUG: 2023-10-28 23:19:52,478: Searching <ConfigEnvFileEnv: None> for COMET_PROJECT_NAME
# DEBUG: 2023-10-28 23:19:52,479: Searching <ConfigDictEnv: {}> for COMET_PROJECT_NAME
# DEBUG: 2023-10-28 23:19:52,483: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,484: Looking up key: file_level, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,487: Searching <ConfigOSEnv> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-10-28 23:19:52,490: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-10-28 23:19:52,492: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-10-28 23:19:52,495: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,496: Looking up key: file_overwrite, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,500: Searching <ConfigOSEnv> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-10-28 23:19:52,504: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-10-28 23:19:52,505: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-10-28 23:19:52,506: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,509: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,512: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,516: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,517: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,518: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,522: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-10-28 23:19:52,523: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-10-28 23:19:52,525: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-10-28 23:19:52,527: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,531: No INI file found: []
# DEBUG: 2023-10-28 23:19:52,533: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:52,535: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:52,538: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:52,539: Looking up key: display_summary, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,541: Searching <ConfigOSEnv> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-10-28 23:19:52,542: Searching <ConfigEnvFileEnv: None> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-10-28 23:19:52,545: Searching <ConfigDictEnv: {}> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-10-28 23:19:52,548: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,550: Looking up key: display_summary_level, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:52,551: Searching <ConfigOSEnv> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-10-28 23:19:52,553: Searching <ConfigEnvFileEnv: None> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-10-28 23:19:52,556: Searching <ConfigDictEnv: {}> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-10-28 23:19:52,558: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,561: Looking up key: code, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,588: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-10-28 23:19:52,590: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-10-28 23:19:52,593: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-10-28 23:19:52,598: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,600: Looking up key: graph, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,602: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-10-28 23:19:52,604: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-10-28 23:19:52,606: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-10-28 23:19:52,636: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,639: Looking up key: parameters, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,651: Searching <ConfigOSEnv> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-10-28 23:19:52,685: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-10-28 23:19:52,687: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-10-28 23:19:52,689: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,692: Looking up key: metrics, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,694: Searching <ConfigOSEnv> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-10-28 23:19:52,697: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-10-28 23:19:52,699: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-10-28 23:19:52,701: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,703: Looking up key: cli_arguments, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,705: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-10-28 23:19:52,707: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-10-28 23:19:52,709: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-10-28 23:19:52,710: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,743: Looking up key: env_details, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,763: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-10-28 23:19:52,764: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-10-28 23:19:52,766: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-10-28 23:19:52,767: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,773: Looking up key: git_metadata, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,890: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-10-28 23:19:52,893: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-10-28 23:19:52,895: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-10-28 23:19:52,896: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,897: Looking up key: git_patch, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,898: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-10-28 23:19:52,899: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-10-28 23:19:52,900: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-10-28 23:19:52,902: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,903: Looking up key: disable, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,904: Searching <ConfigOSEnv> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-10-28 23:19:52,905: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-10-28 23:19:52,906: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-10-28 23:19:52,907: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,908: Looking up key: env_gpu, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,910: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-10-28 23:19:52,911: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-10-28 23:19:52,912: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-10-28 23:19:52,913: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,914: Looking up key: env_host, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,915: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-10-28 23:19:52,916: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-10-28 23:19:52,918: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-10-28 23:19:52,919: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,921: Looking up key: env_cpu, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,923: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-10-28 23:19:52,925: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-10-28 23:19:52,929: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-10-28 23:19:52,930: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,931: Looking up key: env_network, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,932: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_NETWORK
# DEBUG: 2023-10-28 23:19:52,933: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_NETWORK
# DEBUG: 2023-10-28 23:19:52,934: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_NETWORK
# DEBUG: 2023-10-28 23:19:52,935: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,937: Looking up key: env_disk, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,938: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_DISK
# DEBUG: 2023-10-28 23:19:52,939: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_DISK
# DEBUG: 2023-10-28 23:19:52,940: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_DISK
# DEBUG: 2023-10-28 23:19:52,941: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,942: Looking up key: co2, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,943: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-10-28 23:19:52,944: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-10-28 23:19:52,945: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-10-28 23:19:52,946: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,948: Looking up key: histogram_tensorboard, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,949: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-10-28 23:19:52,950: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-10-28 23:19:52,951: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-10-28 23:19:52,952: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,953: Looking up key: weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,954: Searching <ConfigOSEnv> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,955: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,956: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,957: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,958: Looking up key: histogram_weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,959: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,961: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,962: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,963: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,964: Looking up key: weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,965: Searching <ConfigOSEnv> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,966: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,967: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-10-28 23:19:52,968: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,970: Looking up key: histogram_gradients, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,971: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-10-28 23:19:52,972: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-10-28 23:19:52,973: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-10-28 23:19:52,974: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,975: Looking up key: histogram_activations, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,976: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-10-28 23:19:52,977: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-10-28 23:19:52,978: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-10-28 23:19:52,979: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,980: Looking up key: metric_step_rate, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,981: Searching <ConfigOSEnv> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-10-28 23:19:52,982: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-10-28 23:19:52,983: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-10-28 23:19:52,985: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,986: Looking up key: histogram_epoch_rate, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,987: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-10-28 23:19:52,988: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-10-28 23:19:52,989: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-10-28 23:19:52,990: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,991: Looking up key: output_logger, namespace: ['comet', 'auto_log']
# DEBUG: 2023-10-28 23:19:52,992: Searching <ConfigOSEnv> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-10-28 23:19:52,994: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-10-28 23:19:52,995: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-10-28 23:19:52,996: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:52,997: Looking up key: others_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:52,998: Searching <ConfigOSEnv> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-10-28 23:19:52,999: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-10-28 23:19:53,000: Searching <ConfigDictEnv: {}> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-10-28 23:19:53,001: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,003: Looking up key: metrics_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:53,003: Searching <ConfigOSEnv> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-10-28 23:19:53,005: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-10-28 23:19:53,006: Searching <ConfigDictEnv: {}> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-10-28 23:19:53,007: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,008: Looking up key: parameters_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-10-28 23:19:53,009: Searching <ConfigOSEnv> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-10-28 23:19:53,010: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-10-28 23:19:53,011: Searching <ConfigDictEnv: {}> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-10-28 23:19:53,012: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,013: Looking up key: experiment_key, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:53,014: Searching <ConfigOSEnv> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-10-28 23:19:53,015: Searching <ConfigEnvFileEnv: None> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-10-28 23:19:53,016: Searching <ConfigDictEnv: {}> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-10-28 23:19:53,018: Found nothing--returning NO_VALUE
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# DEBUG: 2023-10-28 23:19:53,021: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# DEBUG: 2023-10-28 23:19:53,022: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-10-28 23:19:53,023: Searching <ConfigEnvFileEnv: None> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-10-28 23:19:53,024: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-10-28 23:19:53,025: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,026: Looking up key: url_override, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:53,027: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# DEBUG: 2023-10-28 23:19:53,028: Searching <ConfigEnvFileEnv: None> for COMET_URL_OVERRIDE
# DEBUG: 2023-10-28 23:19:53,029: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# DEBUG: 2023-10-28 23:19:53,030: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,032: Looking up key: http, namespace: ['comet', 'timeout']
# DEBUG: 2023-10-28 23:19:53,033: Searching <ConfigOSEnv> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-10-28 23:19:53,034: Searching <ConfigEnvFileEnv: None> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-10-28 23:19:53,035: Searching <ConfigDictEnv: {}> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-10-28 23:19:53,036: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,037: No INI file found: []
# DEBUG: 2023-10-28 23:19:53,038: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:53,039: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:53,040: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:53,043: No INI file found: []
# DEBUG: 2023-10-28 23:19:53,044: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:53,045: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:53,047: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:53,048: Looking up key: name, namespace: ['comet', 'allow_header']
# DEBUG: 2023-10-28 23:19:53,049: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,050: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,051: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,052: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,053: Looking up key: value, namespace: ['comet', 'allow_header']
# DEBUG: 2023-10-28 23:19:53,054: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,055: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,056: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,057: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,058: No INI file found: []
# DEBUG: 2023-10-28 23:19:53,060: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:53,061: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:53,062: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:53,063: Looking up key: retry_total, namespace: ['comet', 'http_session']
# DEBUG: 2023-10-28 23:19:53,064: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_TOTAL
# DEBUG: 2023-10-28 23:19:53,065: Searching <ConfigEnvFileEnv: None> for COMET_HTTP_SESSION_RETRY_TOTAL
# DEBUG: 2023-10-28 23:19:53,066: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_TOTAL
# DEBUG: 2023-10-28 23:19:53,067: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,068: Looking up key: retry_backoff_factor, namespace: ['comet', 'http_session']
# DEBUG: 2023-10-28 23:19:53,069: Searching <ConfigOSEnv> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# DEBUG: 2023-10-28 23:19:53,070: Searching <ConfigEnvFileEnv: None> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# DEBUG: 2023-10-28 23:19:53,071: Searching <ConfigDictEnv: {}> for COMET_HTTP_SESSION_RETRY_BACKOFF_FACTOR
# DEBUG: 2023-10-28 23:19:53,072: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,075: No INI file found: []
# DEBUG: 2023-10-28 23:19:53,076: No INI file found: ['./.comet.config']
# DEBUG: 2023-10-28 23:19:53,077: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-10-28 23:19:53,078: No INI file found: ['~/.comet.config']
# DEBUG: 2023-10-28 23:19:53,079: Looking up key: name, namespace: ['comet', 'allow_header']
# DEBUG: 2023-10-28 23:19:53,081: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,082: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,083: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-10-28 23:19:53,084: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:53,085: Looking up key: value, namespace: ['comet', 'allow_header']
# DEBUG: 2023-10-28 23:19:53,086: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,087: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,088: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-10-28 23:19:53,089: Found nothing--returning NO_VALUE
# ...
# DEBUG: 2023-10-28 23:19:56,523: Searching <ConfigEnvFileEnv: None> for COMET_SYSTEM_DISK_INTERVAL
# DEBUG: 2023-10-28 23:19:56,527: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_FEATURE-MOVE-PROJECT-TO-WORKSPACE': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-FAIRNESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-NUMERICAL-DISTRIBUTION': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-OUTPUT-METRICS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS-GITHUB': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_VIDEO-PANEL': True}> for COMET_SYSTEM_DISK_INTERVAL
# DEBUG: 2023-10-28 23:19:56,529: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:56,547: Looking up key: distributed_node_identifier, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:56,552: Looking up key: reporting, namespace: ['comet', 'internal']
# DEBUG: 2023-10-28 23:19:56,552: Searching <ConfigOSEnv> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,553: Searching <ConfigOSEnv> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,554: Searching <ConfigEnvFileEnv: None> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,554: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,554: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:56,553: Searching <ConfigEnvFileEnv: None> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,562: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_FEATURE-MOVE-PROJECT-TO-WORKSPACE': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-FAIRNESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-NUMERICAL-DISTRIBUTION': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-OUTPUT-METRICS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS-GITHUB': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_VIDEO-PANEL': True}> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,621: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:56,655: Looking up key: reporting, namespace: ['comet', 'internal']
# DEBUG: 2023-10-28 23:19:56,662: Searching <ConfigOSEnv> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,671: Searching <ConfigEnvFileEnv: None> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,673: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_REPORTING
# DEBUG: 2023-10-28 23:19:56,673: Found nothing--returning NO_VALUE
# DEBUG: 2023-10-28 23:19:56,741: Looking up key: git_directory, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:56,746: Searching <ConfigOSEnv> for COMET_GIT_DIRECTORY
# DEBUG: 2023-10-28 23:19:56,749: Searching <ConfigEnvFileEnv: None> for COMET_GIT_DIRECTORY
# DEBUG: 2023-10-28 23:19:56,751: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_FEATURE-MOVE-PROJECT-TO-WORKSPACE': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-FAIRNESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-NUMERICAL-DISTRIBUTION': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-OUTPUT-METRICS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS-GITHUB': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_VIDEO-PANEL': True}> for COMET_GIT_DIRECTORY
# DEBUG: 2023-10-28 23:19:56,752: Found nothing--returning NO_VALUE
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/arturartikov/medical-appointment/4dbe0c12ab2b4ae09175a701d9846870
#
# DEBUG: 2023-10-28 23:19:56,784: Looking up key: distributed_node_identifier, namespace: ['comet']
# DEBUG: 2023-10-28 23:19:56,790: Searching <ConfigOSEnv> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,794: Searching <ConfigEnvFileEnv: None> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,798: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_FEATURE-MOVE-PROJECT-TO-WORKSPACE': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-FAIRNESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-NUMERICAL-DISTRIBUTION': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-OUTPUT-METRICS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS-GITHUB': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_VIDEO-PANEL': True}> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-10-28 23:19:56,801: Found nothing--returning NO_VALUE

# %% [markdown]
# Класс Experiment — это интерфейс локального кода для Comet. Он определяет множество методов, описанных в официальной документации Comet. Платформа позволяет хранить информацию о коде, логировать графики, гиперпараметры модели (о них вы узнаете дальше в курсе), метрики.

# %% [markdown]
# Давайте рассмотрим некоторые популярные методы:
#
# * log_metric() и log_metrics() — логируют в эксперименте одну или несколько оценочных метрик, таких как accuracy;
# * log_figure() — логирует рисунок;
# * display() — создаёт интерактивную среду в Jupyter, показывающую приборную панель Comet как вывод ячейки;
# * end() — если эксперимент выполняется в Jupyter, этот метод указывает, что эксперимент завершён.

# %% [markdown]
# После завершения эксперимента Comet предоставляет информационную панель, где можно увидеть все залогированные в коде метрики, цифры, параметры и так далее.
#
# Показатели оценки отображаются автоматически. Например, если эксперимент состоит из нескольких шагов, можно легко нарисовать графики, показывающие метрики в зависимости от количества шагов.

# %% [markdown]
# Итак, Comet.ml — это платформа для экспериментов с машинным обучением, которую специалисты по данным используют для отслеживания, сравнения и объяснения своих экспериментов по машинному обучению. Она обеспечивает воспроизведение моделей, простое обслуживание рабочего процесса машинного обучения и бесперебойную совместную работу на протяжении всего жизненного цикла проекта.
#
# Например, вы в команде строите модель оценки спроса на лекарство. Вы можете разделить пайплайн машинного обучения между участниками проекта, при этом каждый участник получит возможность отслеживать все эксперименты каждого этапа в Comet: от логирования визуализаций до подбора параметров обучения модели и оценки её производительности.
